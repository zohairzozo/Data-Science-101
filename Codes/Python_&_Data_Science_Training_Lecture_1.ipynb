# %% [markdown]
# ![1_RiEfzta7FkYiRq44jhSb7g.png](data:image/png;base64,...)

# %% [markdown]
# #DATA SCIENCE WITH IRIS DATASET
# We will focus on the following points:
# *   Data Collection
# *   Data Cleaning/Data Wrangling
# *   Data Visualization
# *   Machine Learning
#
# *Note: If anyone of you wants to code and play with the results, please be my guest!!!*

# %% [markdown]
# # 1.   DATA COLLECTION

# %%
#Imporitng Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# get names of the builtin dataset
sns.get_dataset_names()

# %%
phool = sns.load_dataset("iris")
phool.head(10)

# %% [markdown]
# # 2.   DATA CLEANING/DATA WRANGLING

# %%
phool.isnull().sum()

# %%
phool.dropna()

# %%
phool.describe()

# %%
phool.hist()

# %%
phool.boxplot()

# %% [markdown]
# # 3. DATA VISUALIZATION

# %%
KS = {'color': ['blue', 'red', 'yellow']}
sns.FacetGrid(phool, hue_kws=KS, hue="species") \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend()
plt.show()

# %%
KS = {'color': ['#f7941e', '#1191d0', '#8dc63f']}
sns.FacetGrid(phool, hue_kws=KS, hue="species") \
   .map(plt.scatter, "petal_length", "petal_width") \
   .add_legend()
plt.show()

# %%
ax= sns.boxplot(x="species", y="petal_length", data=phool)
ax= sns.stripplot(x="species", y="petal_length", data=phool, jitter=True, edgecolor="black")

plt.show()

# %%
sns.violinplot(x="species", y="sepal_length",  palette={'#f7941e', '#1191d0', '#8dc63f'}, data=phool, size=6)
plt.show()

# %%
sns.pairplot(data = phool,hue="species", size=3,palette={'#f7941e', '#1191d0', '#8dc63f'}, diag_kind="kde")
plt.show()

# %% [markdown]
# # 4. MACHINE LEARNING

# %%
species_map = {'setosa': 1, 'versicolor': 2, 'virginica': 3}

phool['species'] = phool['species'].map(species_map)

print(phool['species'])

# %%
X = phool[['petal_length','petal_width','sepal_length','sepal_width']]
y = phool[['species']]

print(X)
print(y)

# %% [markdown]
# ## Using Linear Regressor Model

# %%
from sklearn.model_selection import train_test_split    #librarry for splitting the data
from sklearn.linear_model import  LinearRegression      #and because we know we are going to use linear regression for our prediction we import the class as well


#over here we split the data. into the x&y trainer and y&x tester
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.20)

model = LinearRegression()
model = model.fit(X_train,y_train)

# %%
prediction = model.predict(X_test)
prediction

# %%
from sklearn.metrics import r2_score   #r2_score class will help us to calculate and see the score of our predictions

r2_score(y_test, prediction)

# %%
phool = sns.load_dataset("iris")
phool.head(10)

# %%
X = phool[['petal_length','petal_width','sepal_length','sepal_width']]
y = phool[['species']]

print(X)
print(y)

# %% [markdown]
# ## Using Decision Tree Classifier Model

# %%
from sklearn.model_selection import train_test_split    #the tool for split the data
from sklearn.tree import DecisionTreeClassifier    #and because we know we going to use linear regression for our prediction we import the class as well


#over here we split the data. into the x&y trainer and y&x tester
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.20)

model = DecisionTreeClassifier()
model = model.fit(X_train,y_train)

# %%
prediction = model.predict(X_test)
prediction

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(prediction,y_test)
score

# %%
pred = model.predict([[2.1, 3.5, 5.6, 1.7]]
                     )
pred
